# %% [markdown]
# # Model

# %%
# !sudo apt-get install wget ca-certificates
# !wget --quiet -O - https://www.postgresql.org/media/keys/ACCC4CF8.asc | sudo apt-key add -
# !sudo sh -c 'echo "deb http://apt.postgresql.org/pub/repos/apt/ `lsb_release -cs`-pgdg main" >> /etc/apt/sources.list.d/pgdg.list'
# !sudo apt-get update
# !echo "yes" | sudo apt-get install postgresql postgresql-contrib
# !echo "yes" | sudo apt-get install gcc
# !echo "yes" | sudo apt-get install libpq-dev
# !echo "yes" | pip install psycopg2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# wget is already the newest version (1.20.3-1ubuntu1).
# ca-certificates is already the newest version (20201027ubuntu0.20.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/pgdg.list:1 and /etc/apt/sources.list.d/pgdg.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/pgdg.list:1 and /etc/apt/sources.list.d/pgdg.list:2
# E: gnupg, gnupg2 and gnupg1 do not seem to be installed, but one of them is required for this operation
# sh: 1: lsb_release: not found
# Hit:1 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Ign:3 http://apt.postgresql.org/pub/repos/apt -pgdg InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# ...

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 0.23.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author: None
# Author-email: None
# License: new BSD
# Location: /opt/conda/lib/python3.8/site-packages
# Requires: scipy, numpy, joblib, threadpoolctl
# Required-by:

# %% [markdown]
# ## Load data from Postgres

# %%
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = psycopg2.connect(user="postgres",
                              password="ayamgoreng",
                              host="postgres-db",
                              port="5432",
                              database="postgres")

# %%
cursor = conn.cursor()
cursor.execute(" select NOC, Edition, count(Edition) as total_medal from medalist "
              "  where NOC = 'AUS' "
              "  group by NOC, Edition "
              "  Order by Edition "
              )
resultSet = cursor.fetchall()

# %%
for row in resultSet:
   print("NOC = ", row[0], )
   print("Edition = ", row[1])
   print("Total Medal  = ", row[2], "\n")
# Out:
# NOC =  AUS
# Edition =  1896
# Total Medal  =  2
#
# NOC =  AUS
# Edition =  1900
# Total Medal  =  5
#
# NOC =  AUS
# Edition =  1920
# Total Medal  =  6
#
# NOC =  AUS
# Edition =  1924
# Total Medal  =  10
#
# NOC =  AUS
# Edition =  1928
# Total Medal  =  4
#
# NOC =  AUS
# Edition =  1932
# Total Medal  =  5
#
# NOC =  AUS
# Edition =  1936
# Total Medal  =  1
#
# NOC =  AUS
# Edition =  1948
# Total Medal  =  16
#
# NOC =  AUS
# Edition =  1952
# Total Medal  =  20
#
# NOC =  AUS
# Edition =  1956
# Total Medal  =  61
#
# NOC =  AUS
# Edition =  1960
# Total Medal  =  36
#
# NOC =  AUS
# Edition =  1964
# Total Medal  =  42
#
# NOC =  AUS
# Edition =  1968
# Total Medal  =  49
#
# NOC =  AUS
# Edition =  1972
# Total Medal  =  20
#
# NOC =  AUS
# Edition =  1976
# Total Medal  =  24
#
# NOC =  AUS
# Edition =  1980
# Total Medal  =  12
#
# NOC =  AUS
# Edition =  1984
# Total Medal  =  50
#
# NOC =  AUS
# Edition =  1988
# Total Medal  =  34
#
# NOC =  AUS
# Edition =  1992
# ...

# %% [markdown]
# ## Preparation

# %%
lDict = []
for row in resultSet:
   lDict.append({"year":row[1], "total_medal":row[2]})

# %%
df = pd.DataFrame(lDict)

# %%
df.head(100)
# Out:
#     year  total_medal
# 0   1896            2
# 1   1900            5
# 2   1920            6
# 3   1924           10
# 4   1928            4
# 5   1932            5
# 6   1936            1
# 7   1948           16
# 8   1952           20
# 9   1956           61
# 10  1960           36
# 11  1964           42
# 12  1968           49
# 13  1972           20
# 14  1976           24
# 15  1980           12
# 16  1984           50
# 17  1988           34
# 18  1992           57
# 19  1996          132
# 20  2000          183
# 21  2004          157
# 22  2008          149

# %%
df.plot(x ='year', y='total_medal', kind = 'line')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:ayamgoreng@postgres-db:5432/postgres')
sql = df.to_sql('medalist_aus', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b6291ce81488> in <module>
#       1 from sqlalchemy import create_engine
#       2 engine = create_engine('postgresql://postgres:ayamgoreng@postgres-db:5432/postgres')
# ----> 3 sql = df.to_sql('medalist_aus', engine)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# /opt/conda/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ...
